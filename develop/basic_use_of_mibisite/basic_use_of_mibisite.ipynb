# %%
from mibisite import Mibisite
import mibiscreen as mbs
import mibitrans as mbt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from mibisite import Mibisite
#       2 import mibiscreen as mbs
#       3 import mibitrans as mbt
#
# ImportError: cannot import name 'Mibisite' from 'mibisite' (/home/jaro/NLeSC/MIBIREM/mibisite/mibisite/__init__.py)

# %% [markdown]
# ## Initialize Mibisite object

# %%
mysite = Mibisite()

mysite.add_well(well_type="observation", )
mysite.plot()

# %% [markdown]
# ## Perform screening with `mibiscreen`

# %%
my_screening = mbs.screen(mysite)
my_screening.report()

# %%
new_field = mbt.model(mysite)
mysite.addfield(new_field)
